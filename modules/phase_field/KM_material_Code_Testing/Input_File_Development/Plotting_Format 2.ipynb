# %% [markdown]
# Notebook for plotting format

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit 
plt.rc('font',family='Times New Roman')
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rc('axes', labelsize=24)
plt.rc('axes', titlesize=24)
plt.rc('legend', fontsize=20)

# %% [markdown]
# Read outputs in csv format or generate data

# %%
HBR_grain_size = pd.read_csv('/Users/bisws/Projects/HBS/FY24/Milestone/HBR_grain_size.csv')
NorthAnna_grain_size = pd.read_csv('/Users/bisws/Projects/HBS/FY24/Milestone/NorthAnna_grain_size.csv')

location_simulation_HBR = np.array([0.35, 0.5, 0.7])
grain_simulation_HBR = np.array([3.9, 3.4, 0.4])

# %%
width = 100
height = 120

plt.figure(num=None, figsize=(10, 8), dpi=320, facecolor='w', edgecolor='k')
plt.plot(HBR_grain_size['radial_position'], HBR_grain_size['grain_size'], 'b', linewidth=2, label='HB Robinson', markersize = 5)
plt.plot(NorthAnna_grain_size['radial_position'], NorthAnna_grain_size['grain_size'], 'r', linewidth=2, label='North Anna', markersize = 5)
plt.plot(location_simulation_HBR, location_simulation_HBR, 'k*', linewidth=2, label='This Work', markersize = 8)

plt.ylim([0,20])
plt.xlim([0, 1.0])
plt.xlabel('Normalized Radial Location (r/R)')
plt.ylabel('Grain Diameter ($\mu$m)')
# plt.legend(frameon=False) 
plt.legend(bbox_to_anchor=(0.6, 0.75), frameon=False)
plt.show()
# plt.savefig("/Users/bisws/Projects/HBS/FY25/grain_size_exp2_comp.pdf")
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# /tmp/v1/ipykernel_24476/860011780.py:12: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('Grain Diameter ($\mu$m)')
